# %% [markdown]
# # IRIS FLOWER CLASSIFICATION PROJECT

# %% [markdown]
# - The main objective of this project is to build and evaluate multiple classification models to predict the species of IRIS flowers based on their sepal length, sepal width, petal length, and petal width.

# %% [markdown]
# #### Dataset Information
# - The dataset contains 3 classes of 50 instances each, where each class refers to a type of Iris plant.
# - Attribute Information:
#   - Sepal length in cm
#   - Sepal width in cm
#   - Petal length in cm
#   - Petal width in cm
#   - Class: Iris Setosa, Iris Versicolor, Iris Virginica

# %% [markdown]
# #### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Reading the dataset

# %%
iris_df = pd.read_csv("IRIS.csv")
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Shape of dataset

# %%
iris_df.shape
# Out:
# (150, 5)

# %% [markdown]
# - There are 150 rows and 5 columns

# %% [markdown]
# ### Info about the dataframe

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #### Description of data in a dataframe

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
iris_df["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# #### Data Preprocessing
# - Checking if there's any missing values

# %%
iris_df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# - There's no any missing values

# %% [markdown]
# #### EDA (Exploratory Data Analysis)

# %% [markdown]
# #### Univariate Analysis
# - Focuses on analyzing each feature in the dataset independently
#   - DIstribution of each feature is examined to identify its shape, central tendency,, and dispersion
#   - Helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# - Each species are equally present i.e 50

# %%
iris_df['species'].value_counts().plot(kind='bar')
plt.xlabel('Species')
plt.ylabel('Frequency')
plt.show()

# %%
iris_df['species'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <AxesSubplot: ylabel='species'>

# %%
iris_df['species'].hist()
plt.xlabel('Species')
plt.ylabel('Frequency')
plt.show()

# %%
iris_df['sepal_length'].hist()
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
iris_df['sepal_width'].hist()
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
iris_df['petal_length'].hist()
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
iris_df['petal_width'].hist()
plt.title('Histogram of Petal Width')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(iris_df['sepal_length'])
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(iris_df['sepal_width'])
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(iris_df['petal_length'])
# Out:
# <AxesSubplot: >

# %%
sns.boxplot(iris_df['petal_width'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Multivariate Analysis
# - Bivariate analysis

# %%
iris_df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
sns.scatterplot(data=iris_df, x='sepal_length', y='sepal_width',hue='species')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(data=iris_df, x='petal_length', y='petal_width',hue='species')
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(data=iris_df, x='sepal_length', y='petal_length',hue='species')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(data=iris_df, x='sepal_length', y='petal_width',hue='species')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.boxplot(x='species', y='sepal_length', data=iris_df)

plt.title('Box Plot of Sepal Length for Each Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %%
sns.boxplot(x='species', y='sepal_width', data=iris_df)

plt.title('Box Plot of Sepal Length for Each Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %%
sns.boxplot(x='species', y='petal_length', data=iris_df)

plt.title('Box Plot of Sepal Length for Each Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %%
sns.boxplot(x='species', y='petal_width', data=iris_df)

plt.title('Box Plot of Sepal Length for Each Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %%
sns.pairplot(iris_df,hue='species')

# %% [markdown]
# - We got 4 x 4 = 16 graphs as there are 4 attributes and each of them are plotted against each other
# - From the graph we can make conclusion that:
#   - Sepal Length of Iris-setosa is more followed by Iris-versicolor and then Iris-virginica
#   - Sepal Width of Iris-virginica is more followed by Iris-versicolor and the Iris-setosa
#   - Petal Length of Iris-setosa is more followed by Iris-versicolor and then Iris-virginica
#   - Petal Width of Iris-setosa is more followed by Iris-versicolor and then Iris-virginica
#   - Iris-setosa is easily differentiable than other two flower

# %% [markdown]
# # Relation between features using correlation

# %%
iris_df.corr()
# Out:
# <ipython-input-30-1b33314f8075>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_df.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
# Create a figure and axis using plt.subplots() with figsize
fig, ax = plt.subplots(figsize=(8, 6))

# Create the heatmap for the correlation matrix
sns.heatmap(iris_df.corr(), annot=True, ax=ax)

# Show the heatmap
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# <ipython-input-31-036eb1b7edfd>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris_df.corr(), annot=True, ax=ax)

# %% [markdown]
# - The color map represent the correlation values, where positive correlations are shown in warmer colors (closer to 1), negative correlations in cooler colors (closer to -1), and no correlation (perfectly uncorrelated) in white color (close to 0).

# %%
iris_df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# - Here we can see that both length and width of sepal and petals are in numeric form but species is in string
#
# - Machine learning algorithms typically require numeric data as input. Since the 'species' column in the IRIS dataset contains categorical string labels ('setosa', 'versicolor', 'virginica'), we need to convert it into numerical form before training the model.
#
# One common technique to convert categorical data into numerical form is called "label encoding.

# %% [markdown]
# # Label Encoder

# %% [markdown]
# - Converts the labels into numeric form so as to convert it into the machine-readable form
# - Label encoding assigns a unique integer to each category in the column. In this case, 'setosa' might be encoded as 0, 'versicolor' as 1, and 'virginica' as 2.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# Use Label Encoder to convert 'species' column to numerical form
iris_df['species'] = le.fit_transform(iris_df['species'])

# %%
iris_df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 134           6.1          2.6           5.6          1.4        2
# 43            5.0          3.5           1.6          0.6        0
# 77            6.7          3.0           5.0          1.7        1
# 101           5.8          2.7           5.1          1.9        2
# 66            5.6          3.0           4.5          1.5        1

# %% [markdown]
# #### Model Training

# %%
from sklearn.model_selection import train_test_split
# Separate features (attributes) and target (class) from the DataFrame
X = iris_df.drop(columns=['species'])
y = iris_df['species']
# Separate the data into train - 80% and test - 20%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20)

# %% [markdown]
# #### Using Logistic Regression

# %%
# Create and train the Logistic Regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# c:\Users\Jonathan\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Make predictions on the test sets
predicted = model.predict(X_test)

# %% [markdown]
# - The result is converted back to the original categorical label using the 'inverse_transform()' method of the LabelEncoder.

# %%
predicted_label = le.inverse_transform(predicted)
print(predicted_label)
# Out:
# ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-setosa' 'Iris-setosa'
#  'Iris-virginica' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-virginica' 'Iris-virginica' 'Iris-versicolor' 'Iris-setosa'
#  'Iris-virginica' 'Iris-virginica' 'Iris-versicolor' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa']

# %% [markdown]
# #### Evaluate the model

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Accuracy
accuracy = accuracy_score(y_test,predicted)
print("Accuracy",accuracy)
# Out:
# Accuracy 1.0

# %%
# Classification Report
classification_rep = classification_report(y_test,predicted)
print("Classification Report:\n", classification_rep)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# - For class 0 ('setosa'), precision, recall, and F1-score are all 1.0, indicating that the model perfectly predicts this class.
# - For class 1 ('versicolor'), precision is 1.0, meaning all positive predictions are correct, recall is 0.93, meaning it correctly identifies 93% of actual 'versicolor' instances, and the F1-score is 0.97.
# - For class 2 ('virginica'), precision is 0.83, recall is 1.0, and the F1-score is 0.91.
#
# - Overall, the model achieved an accuracy of 0.97, which indicates that it correctly predicted 97% of the instances in the test set.

# %%
conf_matrix = confusion_matrix(y_test,predicted)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Confusion Matrix:
#  [[10  0  0]
#  [ 0  8  0]
#  [ 0  0 12]]

# %% [markdown]
# Total test data is 10 as 20% of 50 is 10

# %% [markdown]
# - The rows represent the actual class labels, and the columns represent the predicted class labels. The three classes are 'setosa', 'versicolor', and 'virginica', represented as 0, 1, and 2, respectively.
#
# - Here's the interpretation for each row:
#
# - Row 1: Actual class 'setosa' (class 0)
#
#     True Positives (TP): 10
#     False Positives (FP): 0
#     False Negatives (FN): 0
#     True Negatives (TN): Not shown (TN for class 0 is the sum of the other elements in row 1)
#
# - Row 2: Actual class 'versicolor' (class 1)
#
#     True Positives (TP): 14
#     False Positives (FP): 0
#     False Negatives (FN): 1
#     True Negatives (TN): Not shown (TN for class 1 is the sum of the other elements in row 2)
#
# - Row 3: Actual class 'virginica' (class 2)
#
#     True Positives (TP): 5
#     False Positives (FP): 0
#     False Negatives (FN): 0
#     True Negatives (TN): Not shown (TN for class 2 is the sum of the other elements in row 3)
#
# - Interpretation:
#
#   - For class 'setosa' (class 0): The model correctly predicted all instances of 'setosa' (True Positives = 10). There are no False Positives or False Negatives for this class, as indicated by zeros in both those cells.
#
#   - For class 'versicolor' (class 1): The model correctly predicted 14 instances of 'versicolor' (True Positives = 14) and incorrectly predicted 1 instance of 'versicolor' as something else (False Negative = 1).
#
#   - For class 'virginica' (class 2): The model correctly predicted all instances of 'virginica' (True Positives = 5). There are no False Positives or False Negatives for this class.
#
# - In summary, the confusion matrix shows that the model performed very well for all classes, with only a single misclassification for class 'versicolor'. The model achieved high precision and recall for all classes, as evident from the precision and recall values in the classification report you provided earlier.

# %% [markdown]
# #### Sample new data to make predictions

# %%
# Creating a dictionary 'new_sample' containing feature valuues for the new sample.
new_sample = {'sepal_length':5.1, 'sepal_width':3.5, 'petal_length': 1.4, 'petal_width': 0.2}

# %%
# Create a DataFrame from the new sample
new_data = pd.DataFrame([new_sample])

# %%
# Make prediction for the new sample
predicted = model.predict(new_data)

# %%
# Convert the numerical prediction back to its original label
predicted_label = le.inverse_transform(predicted)
print("Predicted Species for the New Sample:", predicted_label)
print("Predicted Species for the New Sample:", predicted_label[0])
# Out:
# Predicted Species for the New Sample: ['Iris-setosa']
# Predicted Species for the New Sample: Iris-setosa
